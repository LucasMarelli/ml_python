# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

#Permite mantener una sesión entre suscesivas requests. Mantiene headers, cookies, etc
session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

data['data']
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'slug': 'bitcoin',
#   'num_market_pairs': 10816,
#   'date_added': '2010-07-13T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'sha-256',
#    'store-of-value',
#    'state-channel',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures-portfolio',
#    'galaxy-digital-portfolio',
#    'huobi-capital-portfolio',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital-portfolio',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
#    'paradigm-portfolio',
#    'bitcoin-ecosystem',
#    'ftx-bankruptcy-estate'],
#   'max_supply': 21000000,
#   'circulating_supply': 19621956,
#   'total_supply': 19621956,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 1,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 44724.48554676186,
#     'volume_24h': 25484513439.195442,
#     'volume_change_24h': 60.7206,
#     'percent_change_1h': 0.04727342,
#     'percent_change_24h': 3.90171687,
#     'percent_change_7d': 6.33172285,
#     'percent_change_30d': -4.07232581,
#     'percent_change_60d': 1.96680124,
#     'percent_change_90d': 20.15355641,
#     'market_cap': 877581887521.1971,
#     'market_cap_dominance': 51.422,
#     'fully_diluted_market_cap': 939214196482,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 1027,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'slug': 'ethereum',
#   'num_market_pairs': 8390,
#   'date_added': '2015-08-07T00:00:00.000Z',
#   'tags': ['pos',
#    'smart-contracts',
#    'ethereum-ecosystem',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures-portfolio',
#    'hashkey-capital-portfolio',
#    'kenetic-capital-portfolio',
#    'huobi-capital-portfolio',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital-portfolio',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
#    'paradigm-portfolio',
#    'injective-ecosystem',
#    'layer-1',
#    'ftx-bankruptcy-estate'],
#   'max_supply': None,
#   'circulating_supply': 120180272.95157084,
#   'total_supply': 120180272.95157084,
#   'infinite_supply': True,
#   'platform': None,
#   'cmc_rank': 2,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 2421.690804089727,
#     'volume_24h': 10080010513.721111,
#     'volume_change_24h': 14.6409,
#     'percent_change_1h': -0.21372521,
#     'percent_change_24h': 2.14679987,
#     'percent_change_7d': 6.84103678,
#     'percent_change_30d': 6.33502759,
#     'percent_change_60d': 3.14389082,
#     'percent_change_90d': 16.18800598,
#     'market_cap': 291039461839.81244,
#     'market_cap_dominance': 17.0535,
#     'fully_diluted_market_cap': 291039461839.81,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 825,
#   'name': 'Tether USDt',
#   'symbol': 'USDT',
#   'slug': 'tether',
#   'num_market_pairs': 74374,
#   'date_added': '2015-02-25T00:00:00.000Z',
#   'tags': ['payments',
#    'stablecoin',
#    'asset-backed-stablecoin',
#    'avalanche-ecosystem',
#    'solana-ecosystem',
#    'arbitrum-ecosytem',
#    'moonriver-ecosystem',
#    'injective-ecosystem',
#    'bnb-chain',
#    'usd-stablecoin',
#    'optimism-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 96186132537.35936,
#   'total_supply': 99600626149.74507,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#   'infinite_supply': True,
#   'cmc_rank': 3,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.9997103234008027,
#     'volume_24h': 41029749495.20261,
#     'volume_change_24h': 34.8793,
#     'percent_change_1h': 0.01489963,
#     'percent_change_24h': -0.00244959,
#     'percent_change_7d': 0.05807903,
#     'percent_change_30d': -0.07790902,
#     'percent_change_60d': -0.04658733,
#     'percent_change_90d': -0.05653421,
#     'market_cap': 96158269665.596,
#     'market_cap_dominance': 5.6344,
#     'fully_diluted_market_cap': 99571774179.08,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 1839,
#   'name': 'BNB',
#   'symbol': 'BNB',
#   'slug': 'bnb',
#   'num_market_pairs': 2056,
#   'date_added': '2017-07-25T00:00:00.000Z',
#   'tags': ['marketplace',
#    'centralized-exchange',
#    'payments',
#    'smart-contracts',
#    'alameda-research-portfolio',
#    'multicoin-capital-portfolio',
#    'bnb-chain',
#    'layer-1',
#    'sec-security-token',
#    'alleged-sec-securities',
#    'celsius-bankruptcy-estate'],
#   'max_supply': None,
#   'circulating_supply': 149545866.89272338,
#   'total_supply': 149545866.89272338,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 4,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 316.9543533459411,
#     'volume_24h': 1101079732.3721507,
#     'volume_change_24h': 57.6364,
#     'percent_change_1h': 0.01098144,
#     'percent_change_24h': 4.6236574,
#     'percent_change_7d': 5.99582907,
#     'percent_change_30d': 5.42941869,
#     'percent_change_60d': 32.3336331,
#     'percent_change_90d': 25.68623409,
#     'market_cap': 47399213536.54132,
#     'market_cap_dominance': 2.7774,
#     'fully_diluted_market_cap': 47399213536.54,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 5426,
#   'name': 'Solana',
#   'symbol': 'SOL',
#   'slug': 'solana',
#   'num_market_pairs': 625,
#   'date_added': '2020-04-10T00:00:00.000Z',
#   'tags': ['pos',
#    'platform',
#    'solana-ecosystem',
#    'cms-holdings-portfolio',
#    'kenetic-capital-portfolio',
#    'alameda-research-portfolio',
#    'multicoin-capital-portfolio',
#    'okex-blockdream-ventures-portfolio',
#    'layer-1',
#    'ftx-bankruptcy-estate',
#    'sec-security-token',
#    'alleged-sec-securities'],
#   'max_supply': None,
#   'circulating_supply': 436868967.633608,
#   'total_supply': 569043219.2301668,
#   'infinite_supply': True,
#   'platform': None,
#   'cmc_rank': 5,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 101.43362980222732,
#     'volume_24h': 2143660531.361183,
#     'volume_change_24h': 57.6417,
#     'percent_change_1h': 0.01893591,
#     'percent_change_24h': 6.29974669,
#     'percent_change_7d': 6.6664799,
#     'percent_change_30d': 1.92758808,
#     'percent_change_60d': 39.65358661,
#     'percent_change_90d': 97.64741304,
#     'market_cap': 44313205135.02862,
#     'market_cap_dominance': 2.5965,
#     'fully_diluted_market_cap': 57720119240.86,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 52,
#   'name': 'XRP',
#   'symbol': 'XRP',
#   'slug': 'xrp',
#   'num_market_pairs': 1226,
#   'date_added': '2013-08-04T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'enterprise-solutions',
#    'arrington-xrp-capital-portfolio',
#    'galaxy-digital-portfolio',
#    'a16z-portfolio',
#    'pantera-capital-portfolio',
#    'ftx-bankruptcy-estate'],
#   'max_supply': 100000000000,
#   'circulating_supply': 54436190886,
#   'total_supply': 99987935982,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 6,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 0.5124860063253738,
#     'volume_24h': 917129886.8845323,
#     'volume_change_24h': 8.9013,
#     'percent_change_1h': -0.25050338,
#     'percent_change_24h': 2.00750461,
#     'percent_change_7d': 3.77614664,
#     'percent_change_30d': -8.85343241,
#     'percent_change_60d': -22.30253743,
#     'percent_change_90d': -21.94909668,
#     'market_cap': 27897786066.73185,
#     'market_cap_dominance': 1.6347,
#     'fully_diluted_market_cap': 51248600632.54,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 3408,
#   'name': 'USDC',
#   'symbol': 'USDC',
#   'slug': 'usd-coin',
#   'num_market_pairs': 16626,
#   'date_added': '2018-10-08T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'stablecoin',
#    'asset-backed-stablecoin',
#    'coinbase-ventures-portfolio',
#    'hedera-hashgraph-ecosystem',
#    'fantom-ecosystem',
#    'arbitrum-ecosytem',
#    'moonriver-ecosystem',
#    'bnb-chain',
#    'usd-stablecoin',
#    'optimism-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 27538617109.426632,
#   'total_supply': 27538617109.426632,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   'infinite_supply': False,
#   'cmc_rank': 7,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 0.999955091910999,
#     'volume_24h': 6152961565.469097,
#     'volume_change_24h': 33.5914,
#     'percent_change_1h': -0.00248682,
#     'percent_change_24h': -0.03933464,
#     'percent_change_7d': -0.04784114,
#     'percent_change_30d': -0.02358826,
#     'percent_change_60d': -0.00601903,
#     'percent_change_90d': -0.01299584,
#     'market_cap': 27537380402.758514,
#     'market_cap_dominance': 1.6131,
#     'fully_diluted_market_cap': 27537380402.76,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 2010,
#   'name': 'Cardano',
#   'symbol': 'ADA',
#   'slug': 'cardano',
#   'num_market_pairs': 1067,
#   'date_added': '2017-10-01T00:00:00.000Z',
#   'tags': ['dpos',
#    'pos',
#    'platform',
#    'research',
#    'smart-contracts',
#    'staking',
#    'cardano-ecosystem',
#    'cardano',
#    'layer-1',
#    'sec-security-token',
#    'alleged-sec-securities'],
#   'max_supply': 45000000000,
#   'circulating_supply': 35438342498.504,
#   'total_supply': 36599737145.585,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 8,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.5268158518097906,
#     'volume_24h': 630295728.5865337,
#     'volume_change_24h': 51.5071,
#     'percent_change_1h': -0.94787208,
#     'percent_change_24h': 9.94980566,
#     'percent_change_7d': 7.71489237,
#     'percent_change_30d': 2.1925431,
#     'percent_change_60d': -10.83992955,
#     'percent_change_90d': 40.45509679,
#     'market_cap': 18669480590.07649,
#     'market_cap_dominance': 1.0939,
#     'fully_diluted_market_cap': 23706713331.44,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 5805,
#   'name': 'Avalanche',
#   'symbol': 'AVAX',
#   'slug': 'avalanche',
#   'num_market_pairs': 660,
#   'date_added': '2020-07-13T00:00:00.000Z',
#   'tags': ['defi',
#    'smart-contracts',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'avalanche-ecosystem',
#    'cms-holdings-portfolio',
#    'dragonfly-capital-portfolio',
#    'moonriver-ecosystem',
#    'injective-ecosystem',
#    'real-world-assets',
#    'layer-1'],
#   'max_supply': 720000000,
#   'circulating_supply': 367456650.6259994,
#   'total_supply': 435489560.6259994,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 9,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 35.27855515960221,
#     'volume_24h': 508542182.4922276,
#     'volume_change_24h': 56.2654,
#     'percent_change_1h': -0.17993123,
#     'percent_change_24h': 2.82761588,
#     'percent_change_7d': 6.78081886,
#     'percent_change_30d': -1.35681706,
#     'percent_change_60d': 7.54584528,
#     'percent_change_90d': 162.85623954,
#     'market_cap': 12963339717.871998,
#     'market_cap_dominance': 0.7596,
#     'fully_diluted_market_cap': 25400559714.91,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 74,
#   'name': 'Dogecoin',
#   'symbol': 'DOGE',
#   'slug': 'dogecoin',
#   'num_market_pairs': 888,
#   'date_added': '2013-12-15T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'scrypt',
#    'medium-of-exchange',
#    'memes',
#    'payments',
#    'doggone-doggerel',
#    'bnb-chain',
#    'ftx-bankruptcy-estate'],
#   'max_supply': None,
#   'circulating_supply': 142987776383.7052,
#   'total_supply': 142987776383.7052,
#   'infinite_supply': True,
#   'platform': None,
#   'cmc_rank': 10,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 0.0798902277018003,
#     'volume_24h': 247157485.73676154,
#     'volume_change_24h': 39.8059,
#     'percent_change_1h': -0.01701249,
#     'percent_change_24h': 1.57501082,
#     'percent_change_7d': 1.69162541,
#     'percent_change_30d': 2.40583968,
#     'percent_change_60d': -19.98816202,
#     'percent_change_90d': 7.47543227,
#     'market_cap': 11423326013.868313,
#     'market_cap_dominance': 0.6694,
#     'fully_diluted_market_cap': 11423326013.87,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 1975,
#   'name': 'Chainlink',
#   'symbol': 'LINK',
#   'slug': 'chainlink',
#   'num_market_pairs': 1625,
#   'date_added': '2017-09-20T00:00:00.000Z',
#   'tags': ['platform',
#    'defi',
#    'oracles',
#    'smart-contracts',
#    'substrate',
#    'polkadot',
#    'polkadot-ecosystem',
#    'avalanche-ecosystem',
#    'solana-ecosystem',
#    'framework-ventures-portfolio',
#    'polygon-ecosystem',
#    'fantom-ecosystem',
#    'cardano-ecosystem',
#    'web3',
#    'near-protocol-ecosystem',
#    'arbitrum-ecosytem',
#    'cardano',
#    'injective-ecosystem',
#    'optimism-ecosystem',
#    'real-world-assets',
#    'celsius-bankruptcy-estate'],
#   'max_supply': 1000000000,
#   'circulating_supply': 587099970.4527867,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#   'infinite_supply': False,
#   'cmc_rank': 11,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 18.59670220737129,
#     'volume_24h': 576682729.891698,
#     'volume_change_24h': -3.785,
#     'percent_change_1h': -0.54159453,
#     'percent_change_24h': 1.42836827,
#     'percent_change_7d': 17.70309648,
#     'percent_change_30d': 36.57754696,
#     'percent_change_60d': 15.77631651,
#     'percent_change_90d': 27.19229311,
#     'market_cap': 10918123316.466957,
#     'market_cap_dominance': 0.6397,
#     'fully_diluted_market_cap': 18596702207.37,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 1958,
#   'name': 'TRON',
#   'symbol': 'TRX',
#   'slug': 'tron',
#   'num_market_pairs': 926,
#   'date_added': '2017-09-13T00:00:00.000Z',
#   'tags': ['media',
#    'payments',
#    'tron-ecosystem',
#    'layer-1',
#    'dwf-labs-portfolio',
#    'sec-security-token',
#    'alleged-sec-securities'],
#   'max_supply': None,
#   'circulating_supply': 88093181757.41003,
#   'total_supply': 88093197383.07341,
#   'infinite_supply': True,
#   'platform': None,
#   'cmc_rank': 12,
#   'self_reported_circulating_supply': 71659659264,
#   'self_reported_market_cap': 8771213400.530262,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.12240099228237186,
#     'volume_24h': 340798844.33565366,
#     'volume_change_24h': 20.729,
#     'percent_change_1h': 0.27455266,
#     'percent_change_24h': -1.65854512,
#     'percent_change_7d': 7.61224199,
#     'percent_change_30d': 19.16192268,
#     'percent_change_60d': 13.80421848,
#     'percent_change_90d': 15.29134194,
#     'market_cap': 10782692860.418327,
#     'market_cap_dominance': 0.6318,
#     'fully_diluted_market_cap': 10782694773.02,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 6636,
#   'name': 'Polkadot',
#   'symbol': 'DOT',
#   'slug': 'polkadot-new',
#   'num_market_pairs': 682,
#   'date_added': '2020-08-19T00:00:00.000Z',
#   'tags': ['substrate',
#    'polkadot',
#    'binance-chain',
#    'polkadot-ecosystem',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'arrington-xrp-capital-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'coinfund-portfolio',
#    'fabric-ventures-portfolio',
#    'fenbushi-capital-portfolio',
#    'hashkey-capital-portfolio',
#    'kenetic-capital-portfolio',
#    '1confirmation-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'exnetwork-capital-portfolio',
#    'web3',
#    'spartan-group',
#    'injective-ecosystem',
#    'bnb-chain',
#    'layer-1'],
#   'max_supply': None,
#   'circulating_supply': 1309579899.7679367,
#   'total_supply': 1408676265.0340917,
#   'infinite_supply': True,
#   'platform': None,
#   'cmc_rank': 13,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 6.8810349088538745,
#     'volume_24h': 197963410.86695006,
#     'volume_change_24h': 46.1416,
#     'percent_change_1h': -0.4352166,
#     'percent_change_24h': 2.20922534,
#     'percent_change_7d': 3.29001765,
#     'percent_change_30d': -4.22159835,
#     'percent_change_60d': -4.28848289,
#     'percent_change_90d': 34.09250948,
#     'market_cap': 9011265006.23653,
#     'market_cap_dominance': 0.528,
#     'fully_diluted_market_cap': 9693150554.97,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 3890,
#   'name': 'Polygon',
#   'symbol': 'MATIC',
#   'slug': 'polygon',
#   'num_market_pairs': 1271,
#   'date_added': '2019-04-28T00:00:00.000Z',
#   'tags': ['pos',
#    'platform',
#    'enterprise-solutions',
#    'zero-knowledge-proofs',
#    'scaling',
#    'state-channel',
#    'coinbase-ventures-portfolio',
#    'layer-2',
#    'binance-launchpad',
#    'binance-labs-portfolio',
#    'polygon-ecosystem',
#    'moonriver-ecosystem',
#    'injective-ecosystem',
#    'ftx-bankruptcy-estate',
#    'sec-security-token',
#    'alleged-sec-securities',
#    'modular-blockchain',
#    'standard-crypto-portfolio'],
#   'max_supply': 10000000000,
#   'circulating_supply': 9610751550.897436,
#   'total_supply': 10000000000,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 14,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.8280750475297177,
#     'volume_24h': 296143515.2770982,
#     'volume_change_24h': 20.2271,
#     'percent_change_1h': -0.34936944,
#     'percent_change_24h': 3.84612568,
#     'percent_change_7d': 5.72028873,
#     'percent_change_30d': 3.85757668,
#     'percent_change_60d': -7.96708017,
#     'percent_change_90d': -0.79596768,
#     'market_cap': 7958423547.305703,
#     'market_cap_dominance': 0.4663,
#     'fully_diluted_market_cap': 8280750475.3,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 11419,
#   'name': 'Toncoin',
#   'symbol': 'TON',
#   'slug': 'toncoin',
#   'num_market_pairs': 200,
#   'date_added': '2021-08-26T13:40:22.000Z',
#   'tags': ['pos',
#    'layer-1',
#    'ftx-bankruptcy-estate',
#    'dwf-labs-portfolio',
#    'toncoin-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 3458156790.04254,
#   'total_supply': 5102438336.370167,
#   'infinite_supply': True,
#   'platform': None,
#   'cmc_rank': 15,
#   'self_reported_circulating_supply': 3414166606,
#   'self_reported_market_cap': 7061641124.38482,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 2.068335245261555,
#     'volume_24h': 30559066.04125917,
#     'volume_change_24h': 24.045,
#     'percent_change_1h': 0.40217753,
#     'percent_change_24h': 1.39111588,
#     'percent_change_7d': 0.00718058,
#     'percent_change_30d': -5.20230957,
#     'percent_change_60d': -10.63315898,
#     'percent_change_90d': -17.15207225,
#     'market_cap': 7152627572.485548,
#     'market_cap_dominance': 0.4191,
#     'fully_diluted_market_cap': 10553553047.89,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 8916,
#   'name': 'Internet Computer',
#   'symbol': 'ICP',
#   'slug': 'internet-computer',
#   'num_market_pairs': 214,
#   'date_added': '2021-03-23T00:00:00.000Z',
#   'tags': ['platform',
#    'ai-big-data',
#    'distributed-computing',
#    'collectibles-nfts',
#    'defi',
#    'privacy',
#    'interoperability',
#    'smart-contracts',
#    'dao',
#    'wallet',
#    'storage',
#    'polychain-capital-portfolio',
#    'governance',
#    'launchpad',
#    'lending-borowing',
#    'metaverse',
#    'electric-capital-portfolio',
#    'fenbushi-capital-portfolio',
#    'hashkey-capital-portfolio',
#    'a16z-portfolio',
#    'multicoin-capital-portfolio',
#    'exnetwork-capital-portfolio',
#    'web3',
#    'internet-computer-ecosystem',
#    'bitcoin-ecosystem',
#    'real-world-assets',
#    'layer-1',
#    'sec-security-token',
#    'alleged-sec-securities'],
#   'max_supply': None,
#   'circulating_supply': 457789418.4419707,
#   'total_supply': 514116760.64604694,
#   'platform': {'id': 8916,
#    'name': 'ICP',
#    'symbol': 'ICP',
#    'slug': 'internet-computer',
#    'token_address': 'ryjl3-tyaaa-aaaaa-aaaba-cai'},
#   'infinite_supply': True,
#   'cmc_rank': 16,
#   'self_reported_circulating_supply': 457789418.4419707,
#   'self_reported_market_cap': 5584771930.360236,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 12.199434293102081,
#     'volume_24h': 98774587.34045039,
#     'volume_change_24h': 3.6844,
#     'percent_change_1h': -1.19134125,
#     'percent_change_24h': 1.86731659,
#     'percent_change_7d': 4.48462553,
#     'percent_change_30d': -4.98580288,
#     'percent_change_60d': 128.01193156,
#     'percent_change_90d': 195.08840354,
#     'market_cap': 5584771930.360236,
#     'market_cap_dominance': 0.3272,
#     'fully_diluted_market_cap': 6271933640.48,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 5994,
#   'name': 'Shiba Inu',
#   'symbol': 'SHIB',
#   'slug': 'shiba-inu',
#   'num_market_pairs': 736,
#   'date_added': '2020-08-01T00:00:00.000Z',
#   'tags': ['memes', 'ethereum-ecosystem', 'doggone-doggerel'],
#   'max_supply': None,
#   'circulating_supply': 589290019366697.1,
#   'total_supply': 589534360105428.6,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   'infinite_supply': False,
#   'cmc_rank': 17,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 9.168889587700339e-06,
#     'volume_24h': 148189155.09472683,
#     'volume_change_24h': 101.4947,
#     'percent_change_1h': 0.27188453,
#     'percent_change_24h': 3.46626731,
#     'percent_change_7d': 3.03225201,
#     'percent_change_30d': -1.09509828,
#     'percent_change_60d': -9.2923409,
#     'percent_change_90d': 10.82196463,
#     'market_cap': 5403135122.70704,
#     'market_cap_dominance': 0.3166,
#     'fully_diluted_market_cap': 5405375455.96,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 4943,
#   'name': 'Dai',
#   'symbol': 'DAI',
#   'slug': 'multi-collateral-dai',
#   'num_market_pairs': 3044,
#   'date_added': '2019-11-22T00:00:00.000Z',
#   'tags': ['defi',
#    'stablecoin',
#    'asset-backed-stablecoin',
#    'ethereum-ecosystem',
#    'avalanche-ecosystem',
#    'polygon-ecosystem',
#    'fantom-ecosystem',
#    'arbitrum-ecosytem',
#    'harmony-ecosystem',
#    'moonriver-ecosystem',
#    'bnb-chain',
#    'usd-stablecoin',
#    'optimism-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 5347888595.7464075,
#   'total_supply': 5347888595.7464075,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#   'infinite_supply': True,
#   'cmc_rank': 18,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.9997918265936605,
#     'volume_24h': 137448499.3267167,
#     'volume_change_24h': -11.2652,
#     'percent_change_1h': -0.00270659,
#     'percent_change_24h': -0.03757782,
#     'percent_change_7d': 0.01916057,
#     'percent_change_30d': -0.01390621,
#     'percent_change_60d': -0.06044969,
#     'percent_change_90d': -0.03262589,
#     'market_cap': 5346775307.560707,
#     'market_cap_dominance': 0.3133,
#     'fully_diluted_market_cap': 5346775307.56,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 2,
#   'name': 'Litecoin',
#   'symbol': 'LTC',
#   'slug': 'litecoin',
#   'num_market_pairs': 1112,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable', 'pow', 'scrypt', 'medium-of-exchange'],
#   'max_supply': 84000000,
#   'circulating_supply': 74183244.02208512,
#   'total_supply': 84000000,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 19,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 68.55667140061988,
#     'volume_24h': 262026631.781854,
#     'volume_change_24h': 22.0829,
#     'percent_change_1h': -0.24829397,
#     'percent_change_24h': 0.87749178,
#     'percent_change_7d': 3.59706789,
#     'percent_change_30d': 5.0796324,
#     'percent_change_60d': -12.06481048,
#     'percent_change_90d': -5.79676569,
#     'market_cap': 5085756283.854088,
#     'market_cap_dominance': 0.298,
#     'fully_diluted_market_cap': 5758760397.65,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 1831,
#   'name': 'Bitcoin Cash',
#   'symbol': 'BCH',
#   'slug': 'bitcoin-cash',
#   'num_market_pairs': 842,
#   'date_added': '2017-07-23T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'sha-256',
#    'marketplace',
#    'medium-of-exchange',
#    'store-of-value',
#    'enterprise-solutions',
#    'payments',
#    'bitcoin-ecosystem',
#    'layer-1'],
#   'max_supply': 21000000,
#   'circulating_supply': 19636150,
#   'total_supply': 19636150,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 20,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 241.93713732866522,
#     'volume_24h': 169007078.18823996,
#     'volume_change_24h': 13.7319,
#     'percent_change_1h': -0.19762721,
#     'percent_change_24h': 2.72840105,
#     'percent_change_7d': 3.05398148,
#     'percent_change_30d': -1.56979262,
#     'percent_change_60d': -2.78471173,
#     'percent_change_90d': 0.58979096,
#     'market_cap': 4750713919.156269,
#     'market_cap_dominance': 0.2784,
#     'fully_diluted_market_cap': 5080679883.9,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 7083,
#   'name': 'Uniswap',
#   'symbol': 'UNI',
#   'slug': 'uniswap',
#   'num_market_pairs': 929,
#   'date_added': '2020-09-17T00:00:00.000Z',
#   'tags': ['decentralized-exchange-dex-token',
#    'defi',
#    'dao',
#    'yield-farming',
#    'amm',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'governance',
#    'blockchain-capital-portfolio',
#    'defiance-capital-portfolio',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    'pantera-capital-portfolio',
#    'parafi-capital',
#    'paradigm-portfolio',
#    'arbitrum-ecosytem',
#    'injective-ecosystem',
#    'optimism-ecosystem'],
#   'max_supply': 1000000000,
#   'circulating_supply': 598187015.71,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   'infinite_supply': False,
#   'cmc_rank': 21,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': 0.87712541,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 6.337485420493046,
#     'volume_24h': 69086078.6381565,
#     'volume_change_24h': -11.0217,
#     'percent_change_1h': -0.30774755,
#     'percent_change_24h': 1.18529139,
#     'percent_change_7d': 6.21968831,
#     'percent_change_30d': 7.31055069,
#     'percent_change_60d': -4.58531121,
#     'percent_change_90d': 20.42673423,
#     'market_cap': 3791001490.79037,
#     'market_cap_dominance': 0.2221,
#     'fully_diluted_market_cap': 6337485420.49,
#     'tvl': 4322074661.98526,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 3957,
#   'name': 'UNUS SED LEO',
#   'symbol': 'LEO',
#   'slug': 'unus-sed-leo',
#   'num_market_pairs': 43,
#   'date_added': '2019-05-21T00:00:00.000Z',
#   'tags': ['marketplace',
#    'centralized-exchange',
#    'discount-token',
#    'payments',
#    'kenetic-capital-portfolio',
#    'alameda-research-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 927635171.9,
#   'total_supply': 985239504,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3'},
#   'infinite_supply': False,
#   'cmc_rank': 22,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 4.047571983217916,
#     'volume_24h': 1115215.89901488,
#     'volume_change_24h': -31.7834,
#     'percent_change_1h': 0.07670473,
#     'percent_change_24h': 0.53034928,
#     'percent_change_7d': 2.8691742,
#     'percent_change_30d': 0.46708904,
#     'percent_change_60d': 6.77982823,
#     'percent_change_90d': -0.0073117,
#     'market_cap': 3754670132.429975,
#     'market_cap_dominance': 0.2199,
#     'fully_diluted_market_cap': 3987827813.15,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 1321,
#   'name': 'Ethereum Classic',
#   'symbol': 'ETC',
#   'slug': 'ethereum-classic',
#   'num_market_pairs': 505,
#   'date_added': '2016-07-24T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'ethash',
#    'platform',
#    'smart-contracts',
#    'dcg-portfolio'],
#   'max_supply': 210700000,
#   'circulating_supply': 145449204.03168207,
#   'total_supply': 210700000,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 23,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 25.206038560949175,
#     'volume_24h': 173864769.33863127,
#     'volume_change_24h': 5.599,
#     'percent_change_1h': -0.03199757,
#     'percent_change_24h': 3.13623625,
#     'percent_change_7d': 6.37503985,
#     'percent_change_30d': 27.61925026,
#     'percent_change_60d': 15.05715647,
#     'percent_change_90d': 20.76317396,
#     'market_cap': 3666198245.4819427,
#     'market_cap_dominance': 0.2148,
#     'fully_diluted_market_cap': 5310912324.79,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 3794,
#   'name': 'Cosmos',
#   'symbol': 'ATOM',
#   'slug': 'cosmos',
#   'num_market_pairs': 697,
#   'date_added': '2019-03-14T00:00:00.000Z',
#   'tags': ['platform',
#    'cosmos-ecosystem',
#    'content-creation',
#    'interoperability',
#    'polychain-capital-portfolio',
#    'dragonfly-capital-portfolio',
#    'hashkey-capital-portfolio',
#    '1confirmation-portfolio',
#    'paradigm-portfolio',
#    'exnetwork-capital-portfolio',
#    'injective-ecosystem',
#    'layer-1',
#    'sec-security-token',
#    'alleged-sec-securities'],
#   'max_supply': None,
#   'circulating_supply': 385849375,
#   'total_supply': 385849375,
#   'infinite_supply': True,
#   'platform': None,
#   'cmc_rank': 24,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 9.499114740107508,
#     'volume_24h': 136511384.66290897,
#     'volume_change_24h': 17.273,
#     'percent_change_1h': 0.19373561,
#     'percent_change_24h': 2.03552134,
#     'percent_change_7d': 3.86864464,
#     'percent_change_30d': -2.56237333,
#     'percent_change_60d': -8.15682093,
#     'percent_change_90d': 1.65417181,
#     'market_cap': 3665227485.5237694,
#     'market_cap_dominance': 0.2148,
#     'fully_diluted_market_cap': 3665227485.52,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 11840,
#   'name': 'Optimism',
#   'symbol': 'OP',
#   'slug': 'optimism-ethereum',
#   'num_market_pairs': 458,
#   'date_added': '2022-05-31T16:19:46.000Z',
#   'tags': ['layer-2', 'optimism-ecosystem', 'modular-blockchain'],
#   'max_supply': 4294967296,
#   'circulating_supply': 957378568,
#   'total_supply': 4294967296,
#   'platform': {'id': 11840,
#    'name': 'Optimism',
#    'symbol': 'OP',
#    'slug': 'optimism-ethereum',
#    'token_address': '0x4200000000000000000000000000000000000042'},
#   'infinite_supply': False,
#   'cmc_rank': 25,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 3.3917801874377687,
#     'volume_24h': 259922448.5955489,
#     'volume_change_24h': -15.9307,
#     'percent_change_1h': 0.49510167,
#     'percent_change_24h': 2.18527623,
#     'percent_change_7d': 16.34586491,
#     'percent_change_30d': 3.50390062,
#     'percent_change_60d': 54.64070878,
#     'percent_change_90d': 101.11240238,
#     'market_cap': 3247217658.8199425,
#     'market_cap_dominance': 0.1903,
#     'fully_diluted_market_cap': 14567584980.27,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 22861,
#   'name': 'Celestia',
#   'symbol': 'TIA',
#   'slug': 'celestia',
#   'num_market_pairs': 139,
#   'date_added': '2023-10-31T16:51:41.000Z',
#   'tags': ['platform',
#    'modular-blockchain',
#    'egirl-capital-portfolio',
#    'data-availability'],
#   'max_supply': None,
#   'circulating_supply': 162742157.886909,
#   'total_supply': 1021698630.136909,
#   'platform': {'id': 12220,
#    'name': 'Osmosis',
#    'symbol': 'OSMO',
#    'slug': 'osmosis',
#    'token_address': 'ibc/D79E7D83AB399BFFF93433E54FAA480C191248FC556924A2A8351AE2638B3877'},
#   'infinite_supply': False,
#   'cmc_rank': 26,
#   'self_reported_circulating_supply': 141043527.75,
#   'self_reported_market_cap': 2777239485.7015557,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 19.69065528922546,
#     'volume_24h': 241186035.52001208,
#     'volume_change_24h': 103.2552,
#     'percent_change_1h': 1.218271,
#     'percent_change_24h': 11.83614567,
#     'percent_change_7d': 17.43229705,
#     'percent_change_30d': 24.58079412,
#     'percent_change_60d': 109.45965067,
#     'percent_change_90d': 704.66859425,
#     'market_cap': 3204499731.97583,
#     'market_cap_dominance': 0.1878,
#     'fully_diluted_market_cap': 20117915535.5,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 512,
#   'name': 'Stellar',
#   'symbol': 'XLM',
#   'slug': 'stellar',
#   'num_market_pairs': 572,
#   'date_added': '2014-08-05T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'enterprise-solutions',
#    'decentralized-exchange-dex-token',
#    'smart-contracts',
#    'hashkey-capital-portfolio'],
#   'max_supply': 50001806812,
#   'circulating_supply': 28379332491.06771,
#   'total_supply': 50001787036.71777,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 27,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.10944737862520228,
#     'volume_24h': 67219343.7252429,
#     'volume_change_24h': 17.8026,
#     'percent_change_1h': -0.13159232,
#     'percent_change_24h': 1.61240039,
#     'percent_change_7d': 1.00133527,
#     'percent_change_30d': -5.4785075,
#     'percent_change_60d': -17.7351456,
#     'percent_change_90d': -10.78411167,
#     'market_cap': 3106043548.2803926,
#     'market_cap_dominance': 0.182,
#     'fully_diluted_market_cap': 5472566682.1,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 10603,
#   'name': 'Immutable',
#   'symbol': 'IMX',
#   'slug': 'immutable-x',
#   'num_market_pairs': 242,
#   'date_added': '2021-06-24T00:00:00.000Z',
#   'tags': ['collectibles-nfts',
#    'zero-knowledge-proofs',
#    'gaming',
#    'scaling',
#    'layer-2',
#    'rollups',
#    'arrington-xrp-capital-portfolio',
#    'alameda-research-portfolio'],
#   'max_supply': 2000000000,
#   'circulating_supply': 1355429364.3898141,
#   'total_supply': 2000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xf57e7e7c23978c3caec3c3548e3d615c346e79ff'},
#   'infinite_supply': False,
#   'cmc_rank': 28,
#   'self_reported_circulating_supply': 570354831,
#   'self_reported_market_cap': 1294141188.5868711,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 2.269010654854734,
#     'volume_24h': 78347995.49964274,
#     'volume_change_24h': 3.963,
#     'percent_change_1h': -0.2790054,
#     'percent_change_24h': 3.56422715,
#     'percent_change_7d': 16.39264703,
#     'percent_change_30d': 20.46585598,
#     'percent_change_60d': 24.25271654,
#     'percent_change_90d': 107.75732129,
#     'market_cap': 3075483669.7034683,
#     'market_cap_dominance': 0.1802,
#     'fully_diluted_market_cap': 4538021309.71,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 6535,
#   'name': 'NEAR Protocol',
#   'symbol': 'NEAR',
#   'slug': 'near-protocol',
#   'num_market_pairs': 354,
#   'date_added': '2020-08-11T00:00:00.000Z',
#   'tags': ['platform',
#    'ai-big-data',
#    'staking',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'arrington-xrp-capital-portfolio',
#    'coinfund-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'kenetic-capital-portfolio',
#    'near-protocol-ecosystem',
#    'cross-chain',
#    'injective-ecosystem',
#    'circle-ventures-portfolio',
#    'layer-1',
#    'sec-security-token',
#    'alleged-sec-securities',
#    'account-abstraction',
#    'data-availability'],
#   'max_supply': None,
#   'circulating_supply': 1033454918,
#   'total_supply': 1176118358,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 29,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 2.927553911745359,
#     'volume_24h': 165613284.92441446,
#     'volume_change_24h': 84.015,
#     'percent_change_1h': -0.27064894,
#     'percent_change_24h': 7.37611129,
#     'percent_change_7d': 5.89753644,
#     'percent_change_30d': -10.44671323,
#     'percent_change_60d': 21.87136077,
#     'percent_change_90d': 100.21793706,
#     'market_cap': 3025494987.803379,
#     'market_cap_dominance': 0.1772,
#     'fully_diluted_market_cap': 3443149899.64,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 21794,
#   'name': 'Aptos',
#   'symbol': 'APT',
#   'slug': 'aptos',
#   'num_market_pairs': 332,
#   'date_added': '2022-10-19T01:50:25.000Z',
#   'tags': ['binance-labs-portfolio',
#    'aptos-ecosystem',
#    'circle-ventures-portfolio',
#    'layer-1',
#    'ftx-bankruptcy-estate'],
#   'max_supply': None,
#   'circulating_supply': 339048087.9884213,
#   'total_supply': 1079999172.9738588,
#   'infinite_supply': True,
#   'platform': None,
#   'cmc_rank': 30,
#   'self_reported_circulating_supply': 130000000,
#   'self_reported_market_cap': 1145352912.7524638,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 8.810407021172798,
#     'volume_24h': 94795828.90198626,
#     'volume_change_24h': -4.5777,
#     'percent_change_1h': 0.0080058,
#     'percent_change_24h': 2.53695565,
#     'percent_change_7d': -2.82667552,
#     'percent_change_30d': 7.01410579,
#     'percent_change_60d': 8.28139851,
#     'percent_change_90d': 19.46864864,
#     'market_cap': 2987151654.9284,
#     'market_cap_dominance': 0.175,
#     'fully_diluted_market_cap': 9515232296.43,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 7226,
#   'name': 'Injective',
#   'symbol': 'INJ',
#   'slug': 'injective',
#   'num_market_pairs': 309,
#   'date_added': '2020-09-29T00:00:00.000Z',
#   'tags': ['pos',
#    'platform',
#    'cosmos-ecosystem',
#    'ai-big-data',
#    'defi',
#    'smart-contracts',
#    'cosmos',
#    'binance-smart-chain',
#    'binance-launchpad',
#    'binance-labs-portfolio',
#    'cms-holdings-portfolio',
#    'pantera-capital-portfolio',
#    'web3',
#    'injective-ecosystem',
#    'layer-1'],
#   'max_supply': None,
#   'circulating_supply': 88392222.33,
#   'total_supply': 100000000,
#   'platform': {'id': 7226,
#    'name': 'Injective',
#    'symbol': 'INJ',
#    'slug': 'injective',
#    'token_address': 'inj'},
#   'infinite_supply': False,
#   'cmc_rank': 31,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 33.33373075772899,
#     'volume_24h': 117253142.5806427,
#     'volume_change_24h': 38.0942,
#     'percent_change_1h': -0.23604146,
#     'percent_change_24h': 2.94065988,
#     'percent_change_7d': -1.05728488,
#     'percent_change_30d': -20.56499474,
#     'percent_change_60d': 76.57303508,
#     'percent_change_90d': 86.48875497,
#     'market_cap': 2946442540.2255406,
#     'market_cap_dominance': 0.1726,
#     'fully_diluted_market_cap': 3333373075.77,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 3897,
#   'name': 'OKB',
#   'symbol': 'OKB',
#   'slug': 'okb',
#   'num_market_pairs': 114,
#   'date_added': '2019-04-30T00:00:00.000Z',
#   'tags': ['marketplace',
#    'centralized-exchange',
#    'discount-token',
#    'alameda-research-portfolio',
#    'x1-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 60000000,
#   'total_supply': 300000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x75231f58b43240c9718dd58b4967c5114342a86c'},
#   'infinite_supply': False,
#   'cmc_rank': 32,
#   'self_reported_circulating_supply': 246638974,
#   'self_reported_market_cap': 11918994956.75305,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 48.325675230683736,
#     'volume_24h': 6268881.27678811,
#     'volume_change_24h': 56.6384,
#     'percent_change_1h': -0.24928586,
#     'percent_change_24h': 1.02617553,
#     'percent_change_7d': -0.16713094,
#     'percent_change_30d': -9.53139502,
#     'percent_change_60d': -17.52849862,
#     'percent_change_90d': -20.58715365,
#     'market_cap': 2899540513.841024,
#     'market_cap_dominance': 0.1698,
#     'fully_diluted_market_cap': 14497702569.21,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 20396,
#   'name': 'Kaspa',
#   'symbol': 'KAS',
#   'slug': 'kaspa',
#   'num_market_pairs': 94,
#   'date_added': '2022-06-01T00:03:58.000Z',
#   'tags': ['mineable',
#    'dag',
#    'pow',
#    'store-of-value',
#    'polychain-capital-portfolio',
#    'layer-1'],
#   'max_supply': 28700000000,
#   'circulating_supply': 22612428047.04182,
#   'total_supply': 22612428047.04182,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 33,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.1256915507315878,
#     'volume_24h': 78259176.88210683,
#     'volume_change_24h': 191.0423,
#     'percent_change_1h': -0.16785568,
#     'percent_change_24h': 15.80774952,
#     'percent_change_7d': 27.55783339,
#     'percent_change_30d': 9.47098057,
#     'percent_change_60d': -1.02242289,
#     'percent_change_90d': 32.79691675,
#     'market_cap': 2842191147.039136,
#     'market_cap_dominance': 0.1665,
#     'fully_diluted_market_cap': 3607347506,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 26081,
#   'name': 'First Digital USD',
#   'symbol': 'FDUSD',
#   'slug': 'first-digital-usd',
#   'num_market_pairs': 201,
#   'date_added': '2023-07-26T04:26:40.000Z',
#   'tags': ['stablecoin',
#    'ethereum-ecosystem',
#    'binance-smart-chain',
#    'usd-stablecoin'],
#   'max_supply': None,
#   'circulating_supply': 2667157854.3,
#   'total_supply': 2667157854.3,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xc5f0f7b66764F6ec8C8Dff7BA683102295E16409'},
#   'infinite_supply': False,
#   'cmc_rank': 34,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 1.0018311967395683,
#     'volume_24h': 5349754454.2915125,
#     'volume_change_24h': 42.8509,
#     'percent_change_1h': -0.03626673,
#     'percent_change_24h': 0.24175092,
#     'percent_change_7d': 0.32943609,
#     'percent_change_30d': 0.25364464,
#     'percent_change_60d': 0.2251044,
#     'percent_change_90d': 0.2917075,
#     'market_cap': 2672041945.0667086,
#     'market_cap_dominance': 0.1566,
#     'fully_diluted_market_cap': 2672041945.07,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 2280,
#   'name': 'Filecoin',
#   'symbol': 'FIL',
#   'slug': 'filecoin',
#   'num_market_pairs': 429,
#   'date_added': '2017-12-13T00:00:00.000Z',
#   'tags': ['mineable',
#    'distributed-computing',
#    'filesharing',
#    'storage',
#    'polychain-capital-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'dcg-portfolio',
#    'hashkey-capital-portfolio',
#    'a16z-portfolio',
#    'winklevoss-capital-portfolio',
#    'pantera-capital-portfolio',
#    'web3',
#    'filecoin-ecosystem',
#    'sec-security-token',
#    'alleged-sec-securities'],
#   'max_supply': None,
#   'circulating_supply': 505969073,
#   'total_supply': 1960939158,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 35,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 5.160315343565468,
#     'volume_24h': 105545914.98837988,
#     'volume_change_24h': 14.6507,
#     'percent_change_1h': -0.02989169,
#     'percent_change_24h': 2.90046936,
#     'percent_change_7d': 5.71139701,
#     'percent_change_30d': -5.9864931,
#     'percent_change_60d': 1.53325111,
#     'percent_change_90d': 14.21652713,
#     'market_cap': 2610959970.7714963,
#     'market_cap_dominance': 0.153,
#     'fully_diluted_market_cap': 10119064424.83,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 4642,
#   'name': 'Hedera',
#   'symbol': 'HBAR',
#   'slug': 'hedera',
#   'num_market_pairs': 213,
#   'date_added': '2019-09-17T00:00:00.000Z',
#   'tags': ['dag',
#    'marketplace',
#    'enterprise-solutions',
#    'payments',
#    'dcg-portfolio',
#    'hedera-hashgraph-ecosystem',
#    'layer-1'],
#   'max_supply': 50000000000,
#   'circulating_supply': 33665267274.0024,
#   'total_supply': 50000000000,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 36,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.0763544041886443,
#     'volume_24h': 86638721.84016228,
#     'volume_change_24h': -43.8328,
#     'percent_change_1h': -0.89008607,
#     'percent_change_24h': 4.48653192,
# ...
#   'cmc_rank': 987,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': 4.70759455,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 0.8349738265250927,
#     'volume_24h': 549037.99041583,
#     'volume_change_24h': -11.983,
#     'percent_change_1h': -0.05475431,
#     'percent_change_24h': 1.85548876,
#     'percent_change_7d': 4.14493392,
#     'percent_change_30d': 2.30240883,
#     'percent_change_60d': -4.07382479,
#     'percent_change_90d': 0.94668788,
#     'market_cap': 9184712.091776019,
#     'market_cap_dominance': 0.0005,
#     'fully_diluted_market_cap': 9184712.09,
#     'tvl': 1951041.4475,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 8276,
#   'name': 'Arianee',
#   'symbol': 'ARIA20',
#   'slug': 'arianee-protocol',
#   'num_market_pairs': 14,
#   'date_added': '2021-01-18T00:00:00.000Z',
#   'tags': [],
#   'max_supply': 200000000,
#   'circulating_supply': 33636812.73626919,
#   'total_supply': 200000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xedf6568618a00c6f0908bf7758a16f76b6e04af9'},
#   'infinite_supply': False,
#   'cmc_rank': 988,
#   'self_reported_circulating_supply': 25700280,
#   'self_reported_market_cap': 6956266.086693872,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 0.27066888324539157,
#     'volume_24h': 0,
#     'volume_change_24h': 0,
#     'percent_change_1h': 0,
#     'percent_change_24h': 0,
#     'percent_change_7d': -1.51859717,
#     'percent_change_30d': -13.56537435,
#     'percent_change_60d': -28.41855415,
#     'percent_change_90d': -23.32399685,
#     'market_cap': 9104438.539260346,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 54133776.65,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 23577,
#   'name': 'Sakai Vault',
#   'symbol': 'SAKAI',
#   'slug': 'sakai-vault',
#   'num_market_pairs': 10,
#   'date_added': '2023-02-20T11:09:53.000Z',
#   'tags': ['binance-chain'],
#   'max_supply': 8000000,
#   'circulating_supply': 2081027,
#   'total_supply': 8000000,
#   'platform': {'id': 1839,
#    'name': 'BNB Smart Chain (BEP20)',
#    'symbol': 'BNB',
#    'slug': 'bnb',
#    'token_address': '0x43B35e89d15B91162Dea1C51133C4c93bdd1C4aF'},
#   'infinite_supply': False,
#   'cmc_rank': 989,
#   'self_reported_circulating_supply': 3207660.6869925754,
#   'self_reported_market_cap': 14010168.166544886,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 4.367721381303731,
#     'volume_24h': 2573358.75781568,
#     'volume_change_24h': -14.0638,
#     'percent_change_1h': -0.11451441,
#     'percent_change_24h': 1.86335798,
#     'percent_change_7d': 7.57640545,
#     'percent_change_30d': -31.86189518,
#     'percent_change_60d': 50.95783696,
#     'percent_change_90d': 114.52973141,
#     'market_cap': 9089346.12297036,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 34941771.05,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 20009,
#   'name': 'DexCheck',
#   'symbol': 'DCK',
#   'slug': 'dexcheck',
#   'num_market_pairs': 26,
#   'date_added': '2022-05-06T13:33:50.000Z',
#   'tags': ['ai-big-data',
#    'ethereum-ecosystem',
#    'binance-smart-chain',
#    'launchpad',
#    'analytics',
#    'seedify',
#    'telegram-bot'],
#   'max_supply': 1000000000,
#   'circulating_supply': 174367945.3649945,
#   'total_supply': 980171663.3641759,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x672f4fa517894496b8a958b4b3fca068ce513a39'},
#   'infinite_supply': False,
#   'cmc_rank': 990,
#   'self_reported_circulating_supply': 304187394.4126,
#   'self_reported_market_cap': 15855981.108475443,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.052125700800633376,
#     'volume_24h': 1772082.24914212,
#     'volume_change_24h': 17.1721,
#     'percent_change_1h': -0.87842614,
#     'percent_change_24h': 1.22625764,
#     'percent_change_7d': 18.04355984,
#     'percent_change_30d': 67.05010066,
#     'percent_change_60d': 77.89578564,
#     'percent_change_90d': 132.13421332,
#     'market_cap': 9089051.349316891,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 52125700.8,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 5079,
#   'name': 'apM Coin',
#   'symbol': 'APM',
#   'slug': 'apm-coin',
#   'num_market_pairs': 11,
#   'date_added': '2019-12-27T00:00:00.000Z',
#   'tags': ['ethereum-ecosystem', 'dwf-labs-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 1382500000,
#   'total_supply': 1812500000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xc8c424b91d8ce0137bab4b832b7f7d154156ba6c'},
#   'infinite_supply': False,
#   'cmc_rank': 991,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.006569874577195179,
#     'volume_24h': 918483.77260628,
#     'volume_change_24h': -39.4461,
#     'percent_change_1h': -0.19850833,
#     'percent_change_24h': 0.84174786,
#     'percent_change_7d': 5.93111564,
#     'percent_change_30d': -6.77031182,
#     'percent_change_60d': -13.69233873,
#     'percent_change_90d': 3.87492774,
#     'market_cap': 9082851.602972334,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 11907897.67,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 27615,
#   'name': 'r/FortNiteBR Bricks',
#   'symbol': 'BRICK',
#   'slug': 'bricks',
#   'num_market_pairs': 19,
#   'date_added': '2023-07-18T09:26:55.000Z',
#   'tags': ['communications-social-media', 'reddit-points'],
#   'max_supply': None,
#   'circulating_supply': 111230228,
#   'total_supply': 111230228,
#   'platform': {'id': 139,
#    'name': 'Arbitrum Nova',
#    'symbol': 'ARBITRUM',
#    'slug': 'arbitrum-nova',
#    'token_address': '0x6dcb98f460457fe4952e12779ba852f82ecc62c1'},
#   'infinite_supply': True,
#   'cmc_rank': 992,
#   'self_reported_circulating_supply': 111272593,
#   'self_reported_market_cap': 9086200.03809898,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.08165712502178303,
#     'volume_24h': 163721.26246842,
#     'volume_change_24h': 163.2429,
#     'percent_change_1h': -3.24867685,
#     'percent_change_24h': -3.18751442,
#     'percent_change_7d': 6.51715318,
#     'percent_change_30d': 30.86215871,
#     'percent_change_60d': 29.53639034,
#     'percent_change_90d': 78.12978179,
#     'market_cap': 9082740.633997431,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 9082740.63,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 2934,
#   'name': 'BitKan',
#   'symbol': 'KAN',
#   'slug': 'bitkan',
#   'num_market_pairs': 19,
#   'date_added': '2018-07-30T00:00:00.000Z',
#   'tags': ['services', 'content-creation'],
#   'max_supply': None,
#   'circulating_supply': 9568656725.62034,
#   'total_supply': 10000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1410434b0346f5be678d0fb554e5c7ab620f8f4a'},
#   'infinite_supply': False,
#   'cmc_rank': 993,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.0009410997353212619,
#     'volume_24h': 251084.58179397,
#     'volume_change_24h': 6.9043,
#     'percent_change_1h': 0.61751313,
#     'percent_change_24h': -0.93991238,
#     'percent_change_7d': -5.43898258,
#     'percent_change_30d': -13.0661528,
#     'percent_change_60d': -6.66884012,
#     'percent_change_90d': -17.29667205,
#     'market_cap': 9005060.311861316,
#     'market_cap_dominance': 0.0005,
#     'fully_diluted_market_cap': 9410997.35,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 6180,
#   'name': 'Suku',
#   'symbol': 'SUKU',
#   'slug': 'suku',
#   'num_market_pairs': 34,
#   'date_added': '2020-08-04T00:00:00.000Z',
#   'tags': ['defi'],
#   'max_supply': None,
#   'circulating_supply': 178403406.7949236,
#   'total_supply': 1500000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x0763fdCCF1aE541A5961815C0872A8c5Bc6DE4d7'},
#   'infinite_supply': False,
#   'cmc_rank': 994,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 0.05042692810387548,
#     'volume_24h': 557822.22238064,
#     'volume_change_24h': -30.1031,
#     'percent_change_1h': -0.37926794,
#     'percent_change_24h': -0.2312484,
#     'percent_change_7d': 0.80084645,
#     'percent_change_30d': -0.81510138,
#     'percent_change_60d': 0.31938209,
#     'percent_change_90d': 33.71304205,
#     'market_cap': 8996335.767934063,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 75640392.16,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 22929,
#   'name': 'Verse',
#   'symbol': 'VERSE',
#   'slug': 'verse-token',
#   'num_market_pairs': 28,
#   'date_added': '2022-12-09T08:19:17.000Z',
#   'tags': [],
#   'max_supply': 210000000000,
#   'circulating_supply': 25023542305.60038,
#   'total_supply': 202813393886.73206,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x249cA82617eC3DfB2589c4c17ab7EC9765350a18'},
#   'infinite_supply': False,
#   'cmc_rank': 995,
#   'self_reported_circulating_supply': 25023542305,
#   'self_reported_market_cap': 8990011.101379288,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.00035926212970986834,
#     'volume_24h': 199016.0435134,
#     'volume_change_24h': 0.2534,
#     'percent_change_1h': 0.01170554,
#     'percent_change_24h': 1.07896956,
#     'percent_change_7d': 6.35074488,
#     'percent_change_30d': 4.91456306,
#     'percent_change_60d': -13.71380452,
#     'percent_change_90d': -12.29856565,
#     'market_cap': 8990011.10159498,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 75445047.24,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 23196,
#   'name': 'Grove Coin',
#   'symbol': 'GRV',
#   'slug': 'grove3',
#   'num_market_pairs': 38,
#   'date_added': '2023-01-11T17:31:53.000Z',
#   'tags': [],
#   'max_supply': 100000000,
#   'circulating_supply': 95083335,
#   'total_supply': 99049999.75,
#   'infinite_supply': False,
#   'platform': None,
#   'cmc_rank': 996,
#   'self_reported_circulating_supply': 99049999.75,
#   'self_reported_market_cap': 9364822.877251485,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.09454641999887017,
#     'volume_24h': 1667546.61858313,
#     'volume_change_24h': 4.9316,
#     'percent_change_1h': 0.16322936,
#     'percent_change_24h': 3.58787452,
#     'percent_change_7d': -3.33466546,
#     'percent_change_30d': -12.45693731,
#     'percent_change_60d': -28.67865837,
#     'percent_change_90d': -47.97728504,
#     'market_cap': 8989788.925803272,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 9454642,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 16302,
#   'name': 'UpOnly',
#   'symbol': 'UPO',
#   'slug': 'uponly',
#   'num_market_pairs': 23,
#   'date_added': '2021-12-20T20:33:18.000Z',
#   'tags': [],
#   'max_supply': 160000000,
#   'circulating_supply': 113792290,
#   'total_supply': 160000000,
#   'platform': {'id': 3890,
#    'name': 'Polygon',
#    'symbol': 'MATIC',
#    'slug': 'polygon',
#    'token_address': '0x9dbfc1cbf7a1e711503a29b4b5f9130ebeccac96'},
#   'infinite_supply': False,
#   'cmc_rank': 997,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.07897476211103623,
#     'volume_24h': 1375008.94192694,
#     'volume_change_24h': 9.9525,
#     'percent_change_1h': 1.1090286,
#     'percent_change_24h': 13.4937005,
#     'percent_change_7d': 21.7429656,
#     'percent_change_30d': -21.29625652,
#     'percent_change_60d': -54.35803134,
#     'percent_change_90d': -37.55538904,
#     'market_cap': 8986719.032820046,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 12635961.94,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 21122,
#   'name': 'KLEVA Protocol',
#   'symbol': 'KLEVA',
#   'slug': 'kleva-protocol',
#   'num_market_pairs': 16,
#   'date_added': '2022-07-25T15:56:35.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 44245691.16953321,
#   'total_supply': 54783232.74879753,
#   'platform': {'id': 4256,
#    'name': 'Klaytn',
#    'symbol': 'KLAY',
#    'slug': 'klaytn',
#    'token_address': '0x5fff3a6c16c2208103f318f4713d4d90601a7313'},
#   'infinite_supply': False,
#   'cmc_rank': 998,
#   'self_reported_circulating_supply': 44246104.90997321,
#   'self_reported_market_cap': 8959447.776567442,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 0.20249122029604813,
#     'volume_24h': 245275.70370876,
#     'volume_change_24h': 129.8968,
#     'percent_change_1h': -3.87591751,
#     'percent_change_24h': -9.63939159,
#     'percent_change_7d': -24.66990893,
#     'percent_change_30d': 123.28215579,
#     'percent_change_60d': 112.45871638,
#     'percent_change_90d': 345.47486199,
#     'market_cap': 8959363.99776086,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 11093123.65,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  {'id': 6209,
#   'name': 'Spheroid Universe',
#   'symbol': 'SPH',
#   'slug': 'spheroid-universe',
#   'num_market_pairs': 17,
#   'date_added': '2020-08-05T00:00:00.000Z',
#   'tags': ['vr-ar', 'collectibles-nfts', 'metaverse'],
#   'max_supply': 10000000000,
#   'circulating_supply': 1982280859,
#   'total_supply': 2153698388.28,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0cf46eb152656c7090e769916eb44a138aaa406'},
#   'infinite_supply': False,
#   'cmc_rank': 999,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': None,
#   'last_updated': '2024-02-08T13:05:00.000Z',
#   'quote': {'USD': {'price': 0.004515408941976998,
#     'volume_24h': 52694.39904774,
#     'volume_change_24h': 7.1235,
#     'percent_change_1h': -0.23929159,
#     'percent_change_24h': -4.13335875,
#     'percent_change_7d': -2.4466548,
#     'percent_change_30d': -21.56770165,
#     'percent_change_60d': 4.69506667,
#     'percent_change_90d': -16.93568934,
#     'market_cap': 8950808.716238445,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 45154089.42,
#     'tvl': None,
#     'last_updated': '2024-02-08T13:05:00.000Z'}}},
#  {'id': 8049,
#   'name': 'Tornado Cash',
#   'symbol': 'TORN',
#   'slug': 'torn',
#   'num_market_pairs': 72,
#   'date_added': '2020-12-18T00:00:00.000Z',
#   'tags': ['dao', 'binance-smart-chain', 'optimism-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 5262344.57909121,
#   'total_supply': 9999997.526815,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x77777feddddffc19ff86db637967013e6c6a116c'},
#   'infinite_supply': False,
#   'cmc_rank': 1000,
#   'self_reported_circulating_supply': None,
#   'self_reported_market_cap': None,
#   'tvl_ratio': 0.0232638,
#   'last_updated': '2024-02-08T13:04:00.000Z',
#   'quote': {'USD': {'price': 1.6908048236371702,
#     'volume_24h': 113966.81959859,
#     'volume_change_24h': -11.6738,
#     'percent_change_1h': -0.10315338,
#     'percent_change_24h': 2.09462677,
#     'percent_change_7d': 3.74191662,
#     'percent_change_30d': 9.46008775,
#     'percent_change_60d': 18.44636697,
#     'percent_change_90d': -54.08626494,
#     'market_cap': 8897597.597968332,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 16908044.05,
#     'tvl': 382465385.17389,
#     'last_updated': '2024-02-08T13:04:00.000Z'}}},
#  ...]

# %%
type(data['data'])
# Out:
# list

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_15836\255794193.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
#convierte la lista en dataFrame.
data_frame=pd.json_normalize(data['data'])
data_frame
# Out:
#          id                                 name symbol  \
# 0         1                              Bitcoin    BTC
# 1      1027                             Ethereum    ETH
# 2       825                          Tether USDt   USDT
# 3      1839                                  BNB    BNB
# 4      5426                               Solana    SOL
# ...     ...                                  ...    ...
# 4995  24511  MultiFunctional Environmental Token   MFET
# 4996  27925                            AlphaScan   ASCN
# 4997   3748                                 HXRO   HXRO
# 4998  28132                              BobaCat   PSPS
# 4999  12057                   Dopex Rebate Token   RDPX
#
#                                      slug  num_market_pairs  \
# 0                                 bitcoin             10816
# 1                                ethereum              8390
# 2                                  tether             74374
# 3                                     bnb              2056
# 4                                  solana               625
# ...                                   ...               ...
# 4995  multifunctional-environmental-token                12
# 4996                            alphascan                 2
# 4997                                 hxro                30
# 4998                              bobacat                 2
# 4999                           dopex-rdpx                46
#
#                     date_added  \
# 0     2010-07-13T00:00:00.000Z
# 1     2015-08-07T00:00:00.000Z
# 2     2015-02-25T00:00:00.000Z
# 3     2017-07-25T00:00:00.000Z
# 4     2020-04-10T00:00:00.000Z
# ...                        ...
# 4995  2023-04-18T13:11:58.000Z
# 4996  2023-08-25T09:25:19.000Z
# 4997  2019-02-15T00:00:00.000Z
# 4998  2023-09-20T17:54:39.000Z
# 4999  2021-09-22T20:29:31.000Z
#
#                                                    tags    max_supply  \
# 0     [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1     [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2     [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3     [marketplace, centralized-exchange, payments, ...           NaN
# 4     [pos, platform, solana-ecosystem, cms-holdings...           NaN
# ...                                                 ...           ...
# 4995                                                 []  5.000000e+09
# 4996                                     [telegram-bot]  1.000000e+08
# 4997  [three-arrows-capital-portfolio, solana-ecosys...  1.000000e+09
# 4998                              [philanthropy, memes]  1.000000e+09
# 4999                                [arbitrum-ecosytem]  2.250000e+06
#
#       circulating_supply        total_supply  infinite_supply  platform  \
# 0           1.962196e+07            19621956            False       NaN
# 1           1.201803e+08    120180272.951571             True       NaN
# 2           9.618613e+10  99600626149.745071             True       NaN
# 3           1.495459e+08    149545866.892723            False       NaN
# 4           4.368690e+08    569043219.230167             True       NaN
# ...                  ...                 ...              ...       ...
# 4995        0.000000e+00          5000000000            False       NaN
# 4996        0.000000e+00            50000000            False       NaN
# 4997        0.000000e+00          1000000000            False       NaN
# 4998        0.000000e+00    577172773.251456            False       NaN
# 4999        0.000000e+00             2250000            False       NaN
#
#       cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0            1                               NaN                       NaN
# 1            2                               NaN                       NaN
# 2            3                               NaN                       NaN
# 3            4                               NaN                       NaN
# 4            5                               NaN                       NaN
# ...        ...                               ...                       ...
# 4995      4996                      3.184155e+09              1.743000e+06
# 4996      4997                      1.452000e+07              4.229437e+05
# 4997      4998                      6.103856e+08              5.773594e+07
# 4998      4999                      5.771728e+08              1.961983e+06
# 4999      5000                      1.351057e+06              7.543326e+06
#
#       tvl_ratio              last_updated  quote.USD.price  \
# 0           NaN  2024-02-08T13:05:00.000Z     44724.485547
# 1           NaN  2024-02-08T13:05:00.000Z      2421.690804
# 2           NaN  2024-02-08T13:04:00.000Z         0.999710
# 3           NaN  2024-02-08T13:04:00.000Z       316.954353
# 4           NaN  2024-02-08T13:05:00.000Z       101.433630
# ...         ...                       ...              ...
# 4995        NaN  2024-02-08T13:04:00.000Z         0.000547
# 4996        NaN  2024-02-08T13:05:00.000Z         0.029128
# 4997        NaN  2024-02-08T13:04:00.000Z         0.094589
# 4998        NaN  2024-02-08T13:04:00.000Z         0.003399
# 4999        NaN  2024-02-08T13:04:00.000Z         5.583277
#
#       quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0             2.548451e+10                      60.7206
# 1             1.008001e+10                      14.6409
# 2             4.102975e+10                      34.8793
# 3             1.101080e+09                      57.6364
# 4             2.143661e+09                      57.6417
# ...                    ...                          ...
# 4995          4.649110e+03                     505.4851
# 4996          4.636168e+03                      42.5213
# 4997          4.633793e+03                     -50.1441
# 4998          4.628499e+03                    1514.3143
# 4999          4.616635e+03                     171.7025
#
#       quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                        0.047273                      3.901717
# 1                       -0.213725                      2.146800
# 2                        0.014900                     -0.002450
# 3                        0.010981                      4.623657
# 4                        0.018936                      6.299747
# ...                           ...                           ...
# 4995                    -0.000147                      3.800491
# 4996                     0.000000                     -1.103155
# 4997                    -0.129882                      2.429319
# 4998                    -1.468340                     -0.238906
# 4999                    -0.006417                      0.821048
#
#       quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                        6.331723                     -4.072326
# 1                        6.841037                      6.335028
# 2                        0.058079                     -0.077909
# 3                        5.995829                      5.429419
# 4                        6.666480                      1.927588
# ...                           ...                           ...
# 4995                     9.911067                     10.086174
# 4996                    -8.449308                    -43.927871
# 4997                    17.712092                    -20.925228
# 4998                     0.423642                     10.894695
# 4999                    -1.974493                    -10.424390
#
#       quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                         1.966801                     20.153556
# 1                         3.143891                     16.188006
# 2                        -0.046587                     -0.056534
# 3                        32.333633                     25.686234
# 4                        39.653587                     97.647413
# ...                            ...                           ...
# 4995                      0.042924                    -20.840012
# 4996                    -60.492935                    -44.832552
# 4997                    -42.656876                    -24.268812
# 4998                   1020.519677                   1326.399067
# 4999                     -6.266252                    -84.241097
#
#       quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0             8.775819e+11                         51.4220
# 1             2.910395e+11                         17.0535
# 2             9.615827e+10                          5.6344
# 3             4.739921e+10                          2.7774
# 4             4.431321e+10                          2.5965
# ...                    ...                             ...
# 4995          0.000000e+00                          0.0000
# 4996          0.000000e+00                          0.0000
# 4997          0.000000e+00                          0.0000
# 4998          0.000000e+00                          0.0000
# 4999          0.000000e+00                          0.0000
#
#       quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                           9.392142e+11            NaN
# 1                           2.910395e+11            NaN
# 2                           9.957177e+10            NaN
# 3                           4.739921e+10            NaN
# 4                           5.772012e+10            NaN
# ...                                  ...            ...
# 4995                        2.736990e+06            NaN
# 4996                        2.912836e+06            NaN
# 4997                        9.458928e+07            NaN
# 4998                        3.399300e+06            NaN
# 4999                        1.256237e+07            NaN
#
#         quote.USD.last_updated  platform.id            platform.name  \
# 0     2024-02-08T13:05:00.000Z          NaN                      NaN
# 1     2024-02-08T13:05:00.000Z          NaN                      NaN
# 2     2024-02-08T13:04:00.000Z       1027.0                 Ethereum
# 3     2024-02-08T13:04:00.000Z          NaN                      NaN
# 4     2024-02-08T13:05:00.000Z          NaN                      NaN
# ...                        ...          ...                      ...
# 4995  2024-02-08T13:04:00.000Z       1839.0  BNB Smart Chain (BEP20)
# 4996  2024-02-08T13:05:00.000Z      11841.0                 Arbitrum
# 4997  2024-02-08T13:04:00.000Z       1027.0                 Ethereum
# 4998  2024-02-08T13:04:00.000Z       1027.0                 Ethereum
# 4999  2024-02-08T13:04:00.000Z       1027.0                 Ethereum
#
#      platform.symbol platform.slug                      platform.token_address
# 0                NaN           NaN                                         NaN
# 1                NaN           NaN                                         NaN
# 2                ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3                NaN           NaN                                         NaN
# 4                NaN           NaN                                         NaN
# ...              ...           ...                                         ...
# 4995             BNB           bnb  0x6d23970ce32Cb0F1929bECE7C56D71319e1b4F01
# 4996             ARB      arbitrum  0x1B8d516E2146D7a32Aca0FcBf9482db85fD42c3a
# 4997             ETH      ethereum  0x4bd70556ae3f8a6ec6c4080a0c327b24325438f3
# 4998             ETH      ethereum  0x03049b395147713ae53c0617093675b4b86dde78
# 4999             ETH      ethereum  0x0ff5a8451a839f5f0bb3562689d9a44089738d11
#
# [5000 rows x 36 columns]

# %%
data_frame.filter(items=["name","slug"])
# Out:
#                                      name                                 slug
# 0                                 Bitcoin                              bitcoin
# 1                                Ethereum                             ethereum
# 2                             Tether USDt                               tether
# 3                                     BNB                                  bnb
# 4                                  Solana                               solana
# ...                                   ...                                  ...
# 4995  MultiFunctional Environmental Token  multifunctional-environmental-token
# 4996                            AlphaScan                            alphascan
# 4997                                 HXRO                                 hxro
# 4998                              BobaCat                              bobacat
# 4999                   Dopex Rebate Token                           dopex-rdpx
#
# [5000 rows x 2 columns]
